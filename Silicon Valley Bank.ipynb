# %%
#Importing libraries: Pandas, seaborn, numpy and matplotlib
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

#Setting plt to use the ggplot style
plt.style.use('ggplot')

#Importing the 'figure' function
from matplotlib.pyplot import figure

#Inline is a jupyter command for matplotlib that sets Jupyter to return the plots in the output, rather than opening a new window
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,8)

#Importing the CSV file
#Note: To get the file path, go to the file location, go to properties, copy the path from there and then add the file name
#Preferably by clicking F2 and copying the name
#Note2: Don't forget to add the '.csv' at the end of the path
#Note3: Don't forget to add an 'r' at the beginning of the path, after the parenthesis

#Silicon Valley Bank
df = pd.read_csv(r'C:\Users\Juan\Desktop\DS\SIVB.csv')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  174.660004  176.774994  169.410004  172.119995  172.119995
# 1  2017-01-04  172.130005  179.380005  172.130005  178.979996  178.979996
# 2  2017-01-05  178.289993  179.970001  173.259995  175.169998  175.169998
# 3  2017-01-06  176.410004  179.350006  175.475006  177.520004  177.520004
# 4  2017-01-09  176.339996  176.339996  173.419998  174.330002  174.330002
#
#    Volume
# 0  488819
# 1  597595
# 2  601777
# 3  401672
# 4  495098

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# Date - 0.0%
# Open - 0.0%
# High - 0.0%
# Low - 0.0%
# Close - 0.0%
# Adj Close - 0.0%
# Volume - 0.0%

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.dropna(inplace=True) # Remove missing values
df.drop_duplicates(inplace=True) # Remove duplicates

# %%
# Create a candlestick chart
fig, ax = plt.subplots()
ax.set_title('Candlestick Chart for Signature Bank Stock Prices 2017-2023')
ax.plot(df.index, df['High'], label='High')
ax.plot(df.index, df['Low'], label='Low')
ax.vlines(df.index, df['Open'], df['Close'], color='black', alpha=0.4, linewidth=2)
ax.legend()
